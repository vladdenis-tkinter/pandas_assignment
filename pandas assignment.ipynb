# %%
import json
import pandas as pd
import requests

# %% [markdown]
# # 1

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')

# %%
df.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
max(df['Year'])
# Out:
# 2014

# %%
steal = ['Robbery', 'Burglary', 'Larceny_Theft', 'Vehicle_Theft']

# %%
#summing all 'stealing' crimes
sum = df[steal].sum(axis = 1)

# %%
#percentage of 'stealing' crimes out of all crimes
df['Percentage of stealing per all crimes'] = sum / df['Total']

# %%
df.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft  \
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800
#
#    Percentage of stealing per all crimes
# 0                               0.946617
# 1                               0.947612
# 2                               0.949192
# 3                               0.951203
# 4                               0.948778

# %%
#percentage of murders + violent per population
df['Percent of murdered +violent per population'] = (df['Murder'] + df['Violent']) / df['Population']

# %%
df.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft  \
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800
#
#    Percentage of stealing per all crimes  Percent of murdered per population
# 0                               0.946617                            0.001659
# 1                               0.947612                            0.001629
# 2                               0.949192                            0.001669
# 3                               0.951203                            0.001728
# 4                               0.948778                            0.001954

# %%
#Info about year where was maximum of murders + violent
df[(df['Murder'] + df['Violent']) == max(df['Murder'] + df['Violent'])]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 32  1992   255082000  14438200  1932270  12505900   23760         109060
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft  \
# 32   672480             1126970   2979900        7915200        1610800
#
#     Percentage of stealing per all crimes  Percent of murdered per population
# 32                               0.912744                            0.007668

# %% [markdown]
# # 2

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')

# %%
df2.head()
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# 0  https://vincentarelbundock.github.io/Rdatasets...
# 1  https://vincentarelbundock.github.io/Rdatasets...
# 2  https://vincentarelbundock.github.io/Rdatasets...
# 3  https://vincentarelbundock.github.io/Rdatasets...
# 4  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                  Doc
# 0  https://vincentarelbundock.github.io/Rdatasets...
# 1  https://vincentarelbundock.github.io/Rdatasets...
# 2  https://vincentarelbundock.github.io/Rdatasets...
# 3  https://vincentarelbundock.github.io/Rdatasets...
# 4  https://vincentarelbundock.github.io/Rdatasets...

# %%
#first 5 datasets with maximum Rows
df2.sort_values(by = 'Rows', ascending = False)[:5]
# Out:
#            Package             Item  \
# 1157     openintro         military
# 1007    mosaicData        Birthdays
# 1642     stevedata  wvs_justifbribe
# 1041  nycflights13          flights
# 1641     stevedata        wvs_immig
#
#                                                   Title     Rows  Cols  \
# 1157                           US Military Demographics  1414593     6
# 1007                           US Births in 1969 - 1988   372864     7
# 1642  Attitudes about the Justifiability of Bribe-Ta...   348532     6
# 1041                                       Flights data   336776    19
# 1641  Attitudes about Immigration in the World Value...   310388     6
#
#       n_binary  n_character  n_factor  n_logical  n_numeric  \
# 1157         2            0         4          1          1
# 1007         0            1         1          0          4
# 1642         0            1         0          0          5
# 1041         0            4         0          0         14
# 1641         0            1         0          0          5
#
#                                                     CSV  \
# 1157  https://vincentarelbundock.github.io/Rdatasets...
# 1007  https://vincentarelbundock.github.io/Rdatasets...
# 1642  https://vincentarelbundock.github.io/Rdatasets...
# 1041  https://vincentarelbundock.github.io/Rdatasets...
# 1641  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                     Doc
# 1157  https://vincentarelbundock.github.io/Rdatasets...
# 1007  https://vincentarelbundock.github.io/Rdatasets...
# 1642  https://vincentarelbundock.github.io/Rdatasets...
# 1041  https://vincentarelbundock.github.io/Rdatasets...
# 1641  https://vincentarelbundock.github.io/Rdatasets...

# %% [markdown]
# # 3

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt', sep = ' ')

# %%
df3.head()
# Out:
#           name  calories  sodium  alcohol  cost
# 0    Budweiser       144      15      4.7  0.43
# 1      Schlitz       151      19      4.9  0.43
# 2    Lowenbrau       157      15      0.9  0.48
# 3  Kronenbourg       170       7      5.2  0.73
# 4     Heineken       152      11      5.0  0.77

# %%
#in order to consume as much alcohol as we can let's compute the price of 1% of alcohol for each position and pick 3 cheapest 
df3['Price of 1% of alcohol'] = df3['cost'] / df3['alcohol']

# %%
df3.head()
# Out:
#           name  calories  sodium  alcohol  cost  Price of 1% of alcohol
# 0    Budweiser       144      15      4.7  0.43                0.091489
# 1      Schlitz       151      19      4.9  0.43                0.087755
# 2    Lowenbrau       157      15      0.9  0.48                0.533333
# 3  Kronenbourg       170       7      5.2  0.73                0.140385
# 4     Heineken       152      11      5.0  0.77                0.154000

# %%
#lets sort and pick first 3 products
df3.sort_values(by = 'Price of 1% of alcohol', ascending = True)[:3]
# Out:
#             name  calories  sodium  alcohol  cost  Price of 1% of alcohol
# 5  Old_Milwaukee       145      23      4.6  0.28                0.060870
# 6     Augsberger       175      24      5.5  0.40                0.072727
# 1        Schlitz       151      19      4.9  0.43                0.087755

# %% [markdown]
# # 4

# %%
df4 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')

# %%
df4.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
x = df4['item_price']

# %%
dollar_str = lambda x: x.replace('$', '')
df4_dollar_str = df4['item_price'].apply(dollar_str)

# %%
dollar_float = lambda x: float(x)

# %%
df4['Dollars'] = df4_dollar_str.apply(dollar_float)

# %%
df4.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  Dollars
# 0                                                NaN     $2.39      2.39
# 1                                       [Clementine]     $3.39      3.39
# 2                                            [Apple]     $3.39      3.39
# 3                                                NaN     $2.39      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98     16.98

# %%
df4['Total_price'] = df4['Dollars'] * df4['quantity']

# %%
df4.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  Dollars  \
# 0                                                NaN     $2.39      2.39
# 1                                       [Clementine]     $3.39      3.39
# 2                                            [Apple]     $3.39      3.39
# 3                                                NaN     $2.39      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98     16.98
#
#    Total_price
# 0         2.39
# 1         3.39
# 2         3.39
# 3         2.39
# 4        33.96
